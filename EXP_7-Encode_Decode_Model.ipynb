# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Define the input and output sequences
input_texts = ['I love coding', 'This is a pen', 'She sings well']
target_texts = ['Ich liebe das Coden', 'Das ist ein Stift', 'Sie singt gut']
# Create a set of all unique words in the input and target sequences
input_words = set()
target_words = set()
for input_text, target_text in zip(input_texts, target_texts):
    input_words.update(input_text.split())
    target_words.update(target_text.split())
# Add <sos> and <eos> tokens to target_words
target_words.add('<sos>')
target_words.add('<eos>')
# Create dictionaries to map words to integers
input_word2idx = {word: idx for idx, word in enumerate(input_words)}
input_idx2word = {idx: word for idx, word in enumerate(input_words)}
target_word2idx = {word: idx for idx, word in enumerate(target_words)}
target_idx2word = {idx: word for idx, word in enumerate(target_words)}
# Define the maximum sequence lengths
max_encoder_seq_length = max([len(text.split()) for text in input_texts])
max_decoder_seq_length = max([len(text.split()) for text in target_texts])
# Prepare the encoder input data
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype='float32')
for i, input_text in enumerate(input_texts):
    for t, word in enumerate(input_text.split()):
        encoder_input_data[i, t] = input_word2idx[word]
# Prepare the decoder input and target data
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length), dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, len(target_words)), dtype='float32')
for i, target_text in enumerate(target_texts):
    for t, word in enumerate(target_text.split()):
        decoder_input_data[i, t] = target_word2idx[word]
        if t > 0:
            decoder_target_data[i, t - 1, target_word2idx[word]] = 1.0
# Define the encoder input and LSTM layers
encoder_inputs = Input(shape=(None,))
encoder_embedding = tf.keras.layers.Embedding(len(input_words), 256)(encoder_inputs)
encoder_lstm = LSTM(256, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]
# Define the decoder input and LSTM layers
decoder_inputs = Input(shape=(None,))
decoder_embedding = tf.keras.layers.Embedding(len(target_words), 256)(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding,
initial_state=encoder_states)
decoder_dense = Dense(len(target_words), activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)
# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# Compile and train the model
model.compile(optimizer='adam', loss='categorical_crossentropy',
metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
batch_size=64, epochs=50, validation_split=0.2)
# Define the encoder model to get the encoder states
encoder_model = Model(encoder_inputs, encoder_states)
# Define the decoder model with encoder states as initial state
decoder_state_input_h = Input(shape=(256,))
decoder_state_input_c = Input(shape=(256,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_embedding,
initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)
# Define a function to perform inference and generate translations
def translate(input_sequence):
    states_value = encoder_model.predict(input_sequence)
    target_sequence = np.zeros((1, 1))
    target_sequence[0, 0] = target_word2idx['<sos>']
    stop_condition = False
    translation = []
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_sequence] +
        states_value)
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = target_idx2word[sampled_token_index]
        translation.append(sampled_word)
        if sampled_word == '<eos>' or len(translation) > max_decoder_seq_length:
            stop_condition = True
        target_sequence = np.zeros((1, 1))
        target_sequence[0, 0] = sampled_token_index
        states_value = [h, c]
    return ' '.join(translation)
# Test the model
for input_text in input_texts:
    input_seq = pad_sequences([[input_word2idx[word] for word in input_text.split()]], maxlen=max_encoder_seq_length)
    translated_text = translate(input_seq)
    print('Input:', input_text)
    print('Translated Text:', translated_text)
    print()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 5s 5s/step - loss: 1.9205 - accuracy: 0.1250 - val_loss: 1.2845 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.8891 - accuracy: 0.5000 - val_loss: 1.2887 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.8566 - accuracy: 0.7500 - val_loss: 1.2934 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.8210 - accuracy: 0.7500 - val_loss: 1.2990 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.7805 - accuracy: 0.7500 - val_loss: 1.3057 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.7332 - accuracy: 0.7500 - val_loss: 1.3140 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.6768 - accuracy: 0.7500 - val_loss: 1.3243 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 1/1 [==============================] - 0s 73ms/step - loss: 1.6089 - accuracy: 0.6250 - val_loss: 1.3374 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 1/1 [==============================] - 0s 92ms/step - loss: 1.5269 - accuracy: 0.6250 - val_loss: 1.3544 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 1/1 [==============================] - 0s 87ms/step - loss: 1.4279 - accuracy: 0.6250 - val_loss: 1.3766 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 1/1 [==============================] - 0s 99ms/step - loss: 1.3101 - accuracy: 0.6250 - val_loss: 1.4062 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1741 - accuracy: 0.6250 - val_loss: 1.4458 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 0s 97ms/step - loss: 1.0266 - accuracy: 0.6250 - val_loss: 1.4965 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.8856 - accuracy: 0.6250 - val_loss: 1.5552 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.7711 - accuracy: 0.6250 - val_loss: 1.6188 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6861 - accuracy: 0.7500 - val_loss: 1.6867 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6235 - accuracy: 0.7500 - val_loss: 1.7611 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 1/1 [==============================] - 0s 89ms/step - loss: 0.5782 - accuracy: 0.7500 - val_loss: 1.8464 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.5469 - accuracy: 0.7500 - val_loss: 1.9471 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 1/1 [==============================] - 0s 93ms/step - loss: 0.5263 - accuracy: 0.7500 - val_loss: 2.0661 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.5121 - accuracy: 0.7500 - val_loss: 2.2024 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4994 - accuracy: 0.7500 - val_loss: 2.3508 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 1/1 [==============================] - 0s 104ms/step - loss: 0.4840 - accuracy: 0.7500 - val_loss: 2.5044 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4628 - accuracy: 0.7500 - val_loss: 2.6602 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 1/1 [==============================] - 0s 92ms/step - loss: 0.4334 - accuracy: 0.7500 - val_loss: 2.8222 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 1/1 [==============================] - 0s 94ms/step - loss: 0.3940 - accuracy: 0.7500 - val_loss: 2.9996 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3450 - accuracy: 0.7500 - val_loss: 3.2030 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2912 - accuracy: 0.7500 - val_loss: 3.4389 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 1/1 [==============================] - 0s 88ms/step - loss: 0.2402 - accuracy: 0.7500 - val_loss: 3.7050 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1984 - accuracy: 0.7500 - val_loss: 3.9848 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1661 - accuracy: 0.7500 - val_loss: 4.2483 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1379 - accuracy: 0.7500 - val_loss: 4.4695 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1125 - accuracy: 0.7500 - val_loss: 4.6417 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0935 - accuracy: 0.7500 - val_loss: 4.7769 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0826 - accuracy: 0.7500 - val_loss: 4.8992 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0774 - accuracy: 0.7500 - val_loss: 5.0327 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0739 - accuracy: 0.7500 - val_loss: 5.1891 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0703 - accuracy: 0.7500 - val_loss: 5.3627 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0676 - accuracy: 0.7500 - val_loss: 5.5331 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0660 - accuracy: 0.7500 - val_loss: 5.6761 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0635 - accuracy: 0.7500 - val_loss: 5.7772 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0594 - accuracy: 0.7500 - val_loss: 5.8380 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0555 - accuracy: 0.7500 - val_loss: 5.8713 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0530 - accuracy: 0.7500 - val_loss: 5.8939 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0509 - accuracy: 0.7500 - val_loss: 5.9192 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0483 - accuracy: 0.7500 - val_loss: 5.9518 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0449 - accuracy: 0.7500 - val_loss: 5.9885 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0414 - accuracy: 0.7500 - val_loss: 6.0215 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0386 - accuracy: 0.7500 - val_loss: 6.0430 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0367 - accuracy: 0.7500 - val_loss: 6.0486 - val_accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Input: I love coding
# Translated Text: liebe das Coden Coden ist
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Input: This is a pen
# Translated Text: ist ein Stift Stift ist
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Input: She sings well
# Translated Text: liebe das Coden ist ist

# %%
from keras.utils import plot_model

plot_model(encoder_model, to_file='model_structure.png', show_shapes=True, show_layer_names=True)

# %%
plot_model(decoder_model, to_file='model_structure.png', show_shapes=True, show_layer_names=True)
